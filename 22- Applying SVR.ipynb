# %% [markdown]
# # 1. Imported Needed Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix , f1_score , r2_score , precision_score , recall_score 
from sklearn.model_selection import train_test_split 
from sklearn.svm import SVR ,SVC
from sklearn.preprocessing import LabelEncoder , OneHotEncoder

# %% [markdown]
# # 2. Lodaded Data

# %%
data = pd.read_csv('D:\\Array Diploma\\Data\\forestfires.csv')
data
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %% [markdown]
# * Show Data Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %% [markdown]
# # 3. Applying Label Encoder
# * On [Month - Day ] Columns Because Convert From Object Data To Numeric Data

# %%
#Applying Label Encoder 
LE = LabelEncoder()
data['month'] = LE.fit_transform(data['month'])
data['day'] = LE.fit_transform(data['day'])

# %%
data.head(50)
# Out:
#     X  Y  month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 0   7  5      7    0  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.0
# 1   7  4     10    5  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.0
# 2   7  4     10    2  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.0
# 3   8  6      7    0  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.0
# 4   8  6      7    3  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.0
# 5   8  6      1    3  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.0
# 6   8  6      1    1  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.0
# 7   8  6      1    1  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.0
# 8   8  6     11    5  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.0
# 9   7  5     11    2  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.0
# 10  7  5     11    2  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.0
# ...

# %% [markdown]
# # 4. Convert All Data From Integer To Float

# %%
data = data.astype(float)
data
# Out:
#        X    Y  month  day  FFMC    DMC     DC   ISI  temp    RH  wind  rain  \
# 0    7.0  5.0    7.0  0.0  86.2   26.2   94.3   5.1   8.2  51.0   6.7   0.0
# 1    7.0  4.0   10.0  5.0  90.6   35.4  669.1   6.7  18.0  33.0   0.9   0.0
# 2    7.0  4.0   10.0  2.0  90.6   43.7  686.9   6.7  14.6  33.0   1.3   0.0
# 3    8.0  6.0    7.0  0.0  91.7   33.3   77.5   9.0   8.3  97.0   4.0   0.2
# 4    8.0  6.0    7.0  3.0  89.3   51.3  102.2   9.6  11.4  99.0   1.8   0.0
# ..   ...  ...    ...  ...   ...    ...    ...   ...   ...   ...   ...   ...
# 512  4.0  3.0    1.0  3.0  81.6   56.7  665.6   1.9  27.8  32.0   2.7   0.0
# 513  2.0  4.0    1.0  3.0  81.6   56.7  665.6   1.9  21.9  71.0   5.8   0.0
# 514  7.0  4.0    1.0  3.0  81.6   56.7  665.6   1.9  21.2  70.0   6.7   0.0
# 515  1.0  4.0    1.0  2.0  94.4  146.0  614.7  11.3  25.6  42.0   4.0   0.0
# 516  6.0  3.0    9.0  5.0  79.5    3.0  106.7   1.1  11.8  31.0   4.5   0.0
#
#       area
# 0     0.00
# 1     0.00
# 2     0.00
# ...

# %% [markdown]
# # Applying Normalization And Make Shuflling For Data

# %%
#from sklearn.preprocessing import MaxAbsScaler
#Scalar = MaxAbsScaler()
#data = Scalar.fit_transform(data)

# %%
data
# Out:
#        X    Y  month  day  FFMC    DMC     DC   ISI  temp    RH  wind  rain  \
# 0    7.0  5.0    7.0  0.0  86.2   26.2   94.3   5.1   8.2  51.0   6.7   0.0
# 1    7.0  4.0   10.0  5.0  90.6   35.4  669.1   6.7  18.0  33.0   0.9   0.0
# 2    7.0  4.0   10.0  2.0  90.6   43.7  686.9   6.7  14.6  33.0   1.3   0.0
# 3    8.0  6.0    7.0  0.0  91.7   33.3   77.5   9.0   8.3  97.0   4.0   0.2
# 4    8.0  6.0    7.0  3.0  89.3   51.3  102.2   9.6  11.4  99.0   1.8   0.0
# ..   ...  ...    ...  ...   ...    ...    ...   ...   ...   ...   ...   ...
# 512  4.0  3.0    1.0  3.0  81.6   56.7  665.6   1.9  27.8  32.0   2.7   0.0
# 513  2.0  4.0    1.0  3.0  81.6   56.7  665.6   1.9  21.9  71.0   5.8   0.0
# 514  7.0  4.0    1.0  3.0  81.6   56.7  665.6   1.9  21.2  70.0   6.7   0.0
# 515  1.0  4.0    1.0  2.0  94.4  146.0  614.7  11.3  25.6  42.0   4.0   0.0
# 516  6.0  3.0    9.0  5.0  79.5    3.0  106.7   1.1  11.8  31.0   4.5   0.0
#
#       area
# 0     0.00
# 1     0.00
# 2     0.00
# ...

# %%
#Shuffle Data
#from sklearn.utils import shuffle
#data =shuffle(data,random_state=0)

# %% [markdown]
# # 5. Data
# 1. Divided Data Two Types (Input Data (x_data) , Output Data (y_data))
# 2. Splitting Data Two (Train ,Test)

# %%
x_data = data.iloc[:,:-1]
y_data = data.iloc[:,-1]
print('The Shape Of X Data Is ==> ',x_data.shape)#
print('The Shape Of Y Data Is ==> ',y_data.shape)
# Out:
# The Shape Of X Data Is ==>  (517, 12)
# The Shape Of Y Data Is ==>  (517,)

# %% [markdown]
# # 6. Applying Linear Regression

# %%
from sklearn.linear_model import LinearRegression ,SGDRegressor
from sklearn.metrics import mean_absolute_error , mean_squared_error , median_absolute_error , accuracy_score , r2_score
x1_train,x1_test ,y1_train,y1_test = train_test_split(x_data ,y_data ,test_size=0.25 ,random_state=0)
LinearregressionModel = LinearRegression()
LinearregressionModel.fit(x1_train,y1_train)
#==============================================================================================================
print('Linear Regression Train Score is : ' , LinearregressionModel.score(x1_train, y1_train))
print('Linear Regression Test Score is : ' , LinearregressionModel.score(x1_test, y1_test))
print('Linear Regression Coef is : ' , LinearregressionModel.coef_)
print('Linear Regression intercept is : ' , LinearregressionModel.intercept_)
print('----------------------------------------------------')
#Calculating Prediction
y_pred = LinearregressionModel.predict(x1_test)
print('Real Value for Linear Regression is      : ' ,list(y1_test[:5]))
print('Predicted Value for Linear Regression is : ' ,list(y_pred[:5]))
print('----------------------------------------------------')
#----------------------------------------------------
#Calculating Mean Absolute Error
MAEValue = mean_absolute_error(y1_test, y_pred, multioutput='uniform_average') # it can be raw_values
print('Mean Absolute Error Value is : ', MAEValue)
print('----------------------------------------------------')
#----------------------------------------------------
#Calculating Mean Squared Error
MSEValue = mean_squared_error(y1_test, y_pred, multioutput='uniform_average') # it can be raw_values
print('Mean Squared Error Value is : ', MSEValue)
#----------------------------------------------------
print('----------------------------------------------------')
#Calculating Median Squared Error
MdSEValue = median_absolute_error(y1_test, y_pred)
print('Median Squared Error Value is : ', MdSEValue )
#-----------------------------------------------------------------------
print('----------------------------------------------------')
R2_Score = r2_score(y1_test,y_pred)
print('The Accuracy Of The Program Is ==> ',R2_Score*100)
# Out:
# Linear Regression Train Score is :  0.030529114671725477
# Linear Regression Test Score is :  0.004356121311621108
# Linear Regression Coef is :  [ 1.50917148  0.8470387   0.37905601  0.72055638 -0.11562266  0.12344975
#  -0.01782199 -0.35155911  0.46834166 -0.16995014  0.98313674 -2.12254792]
# Linear Regression intercept is :  -0.029083801574946833
# ----------------------------------------------------
# Real Value for Linear Regression is      :  [27.35, 0.0, 2.18, 88.49, 2.69]
# Predicted Value for Linear Regression is :  [12.194240547886965, 6.0867315828473405, 13.680504375448116, 21.119995243768614, 13.491084487133007]
# ----------------------------------------------------
# Mean Absolute Error Value is :  23.600103019604983
# ----------------------------------------------------
# Mean Squared Error Value is :  9737.862979560166
# ----------------------------------------------------
# Median Squared Error Value is :  8.686904593153876
# ...

# %% [markdown]
# # Applying SGD

# %%
# The 'loss' parameter of SGDRegressor must be a str among {'squared_epsilon_insensitive', 'huber', 'squared_error', 'epsilon_insensitive'}
x_train,x_test ,y_train,y_test = train_test_split(x_data ,y_data ,test_size=0.25 ,random_state=0)
SGD = SGDRegressor(loss='huber',alpha=0.01,max_iter=300000,verbose=2,epsilon=0.001)
SGD.fit(x_train,y_train)
#Calculating Details
print('SGD Regression Train Score is : ' , SGD.score(x_train, y_train))
print('----------------------------------------------------')
print('SGD Regression Test Score is : ' , SGD.score(x_test, y_test))
print('----------------------------------------------------')
print('SGD Regression Coef is : ' , SGD.coef_)
print('----------------------------------------------------')
print('SGD Regression intercept is : ' , SGD.intercept_)
print('----------------------------------------------------')
#Calculating Prediction
y_pred = SGD.predict(x_test)
print('Predicted Value for SGD Regression is : ' , list(y_pred[:5]))
#----------------------------------------------------
#Calculating Mean Absolute Error
MAEValue = mean_absolute_error(y_test, y_pred, multioutput='uniform_average') # it can be raw_values
print('Mean Absolute Error Value is : ', MAEValue)
#----------------------------------------------------
print('----------------------------------------------------')
#Calculating Mean Squared Error
MSEValue = mean_squared_error(y_test, y_pred, multioutput='uniform_average') # it can be raw_values
print('Mean Squared Error Value is : ', MSEValue)
#----------------------------------------------------
print('----------------------------------------------------')
#Calculating Median Squared Error
MdSEValue = median_absolute_error(y_test, y_pred)
print('Median Squared Error Value is : ', MdSEValue )
print('----------------------------------------------------')
#=======================================================================================================
R2_Score = r2_score(y_test,y_pred)
print('The Accuracy Of The Program Is ==> ',R2_Score*100)
# Out:
# -- Epoch 1
# Norm: 0.00, NNZs: 12, Bias: 0.000013, T: 387, Avg. loss: 0.010740
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 12, Bias: 0.000012, T: 774, Avg. loss: 0.010582
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 12, Bias: 0.000016, T: 1161, Avg. loss: 0.010519
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 12, Bias: 0.000014, T: 1548, Avg. loss: 0.010578
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 12, Bias: 0.000003, T: 1935, Avg. loss: 0.010482
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 12, Bias: 0.000001, T: 2322, Avg. loss: 0.010488
# Total training time: 0.00 seconds.
# Convergence after 6 epochs took 0.00 seconds
# SGD Regression Train Score is :  -0.043721835508275575
# ----------------------------------------------------
# SGD Regression Test Score is :  -0.03806227665530337
# ----------------------------------------------------
# ...

# %%
from sklearn.neural_network import MLPRegressor
MLPModel = MLPRegressor(hidden_layer_sizes=(200,5),activation='identity',solver='lbfgs',tol=0.00001,verbose=1,random_state=None , max_iter=100000,alpha=0.001,learning_rate_init=0.002)
x2_train,x2_test ,y2_train,y2_test = train_test_split(x_data ,y_data ,test_size=0.25 ,random_state=0)
MLPModel.fit(x2_train,y2_train)
#Calculating Details
print('MLPRegressorModel Train Score is : ' , MLPModel.score(x2_train, y2_train))
print('MLPRegressorModel Test Score is : ' , MLPModel.score(x2_test, y2_test))
print('MLPRegressorModel loss is : ' , MLPModel.loss_)
print('MLPRegressorModel No. of iterations is : ' , MLPModel.n_iter_)
print('MLPRegressorModel No. of layers is : ' , MLPModel.n_layers_)
print('MLPRegressorModel last activation is : ' , MLPModel.out_activation_)
print('----------------------------------------------------')
#Calculating Prediction
y2_pred = MLPModel.predict(x2_test)
print('Predicted Value for MLPRegressorModel is : ' , y2_pred[:10])
R2_Score = r2_score(y2_test,y2_pred)
print('The Accuracy Of The Program Is ==> ',R2_Score*100)
# Out:
# MLPRegressorModel Train Score is :  0.030525905545475296
# MLPRegressorModel Test Score is :  0.004325072033267263
# MLPRegressorModel loss is :  1014.4371827994695
# MLPRegressorModel No. of iterations is :  410
# MLPRegressorModel No. of layers is :  4
# MLPRegressorModel last activation is :  identity
# ----------------------------------------------------
# Predicted Value for MLPRegressorModel is :  [12.28505435  5.91920416 13.59651091 21.20554383 13.51533899 14.92872084
#  17.15634131  4.63429268 19.51864679 -0.16451101]
# The Accuracy Of The Program Is ==>  0.4325072033267263

# %%
#The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'absolute_error', 'squared_error', 'friedman_mse'}. Got 'gini' instead.
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor(n_estimators=10000,criterion='friedman_mse',max_depth=None,random_state=0,n_jobs=-1)
x3_train,x3_test ,y3_train,y3_test = train_test_split(x_data ,y_data ,test_size=0.25 ,random_state=0)
RF.fit(x3_train,y3_train)
#Calculating Details
print('RandomForestClassifierModel Train Score is : ' , RF.score(x3_train, y3_train))
print('RandomForestClassifierModel Test Score is : ' , RF.score(x3_test, y3_test))
print('RandomForestClassifierModel features importances are : ' , RF.feature_importances_)
print('----------------------------------------------------')
#Calculating Prediction
y_pred = RF.predict(x3_test)
print('Predicted Value for RandomForestClassifierModel is : ' , y_pred[:5])
print('----------------------------------------------------')
R2_Score = r2_score(y3_test,y_pred)
print('The Accuracy Of The Program Is ==> ',R2_Score*100)
#====================================================================================
# Out:
# RandomForestClassifierModel Train Score is :  0.8391761804975255
# RandomForestClassifierModel Test Score is :  -0.12326728369458428
# RandomForestClassifierModel features importances are :  [0.04240963 0.07359002 0.01620346 0.03300499 0.04416477 0.253145
#  0.06455852 0.03989011 0.25029297 0.12885908 0.05326054 0.0006209 ]
# ----------------------------------------------------
# Predicted Value for RandomForestClassifierModel is :  [19.95145247  8.906097   11.80291058  6.00451533  8.37052511]
# ----------------------------------------------------
# The Accuracy Of The Program Is ==>  -12.32672836945843

# %%
from sklearn.neighbors import KNeighborsRegressor
x4_train,x4_test ,y4_train,y4_test = train_test_split(x_data ,y_data ,test_size=0.25 ,random_state=0)
model = KNeighborsRegressor(n_neighbors=5,weights='uniform',metric='minkowski',algorithm='ball_tree',leaf_size=30)
model.fit(x4_train,y4_train)
#Calculating Details
print('KNeighborsRegressorModel Train Score is : ' , model.score(x4_train, y4_train))
print('KNeighborsRegressorModel Test Score is : ' , model.score(x4_test, y4_test))
print('----------------------------------------------------')
138
#Calculating Prediction
y_pred4 = model.predict(x4_test)
print('Predicted Value for KNeighborsRegressorModel is : ' , y_pred4[:10])
#----------------------------------------------------
#Calculating Mean Absolute Error
MAEValue = mean_absolute_error(y4_test, y_pred4, multioutput='uniform_average') # it can be raw_values
print('Mean Absolute Error Value is : ', MAEValue)
#----------------------------------------------------
#Calculating Mean Squared Error
MSEValue = mean_squared_error(y4_test, y_pred4, multioutput='uniform_average') # it can be raw_values
print('Mean Squared Error Value is : ', MSEValue)
#----------------------------------------------------
#Calculating Median Squared Error
MdSEValue = median_absolute_error(y4_test, y_pred4)
print('Median Squared Error Value is : ', MdSEValue )
print('----------------------------------------------------')
R2_Score = r2_score(y4_test,y_pred4)
print('The Accuracy Of The Program Is ==> ',R2_Score*100)
# Out:
# KNeighborsRegressorModel Train Score is :  0.23264223107206927
# KNeighborsRegressorModel Test Score is :  0.0032175291562180908
# ----------------------------------------------------
# Predicted Value for KNeighborsRegressorModel is :  [10.47   1.548  6.994  8.226  2.544 10.09  10.976  0.434 39.094  1.746]
# Mean Absolute Error Value is :  23.744061538461544
# Mean Squared Error Value is :  9748.998943569228
# Median Squared Error Value is :  5.053000000000001
# ----------------------------------------------------
# The Accuracy Of The Program Is ==>  0.3217529156218091
